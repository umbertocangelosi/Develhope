# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('world_alcohol.csv')

# %%
df.head(10)
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98
# 5  1987         Americas              Guatemala          Other           0.00
# 6  1987           Africa              Mauritius           Wine           0.13
# 7  1985           Africa                 Angola        Spirits           0.39
# 8  1986         Americas    Antigua and Barbuda        Spirits           1.55
# 9  1984           Africa                Nigeria          Other           6.10

# %% [markdown]
# ### Write a Pandas program to filter those records where WHO region matches with multiple values (Africa, Eastern Mediterranean, Europe) from world alcohol consumption dataset

# %%
df.drop_duplicates('WHO region')
# Out:
#     Year             WHO region       Country Beverage Types  Display Value
# 0   1986        Western Pacific      Viet Nam           Wine           0.00
# 1   1986               Americas       Uruguay          Other           0.50
# 2   1985                 Africa  Cte d'Ivoire           Wine           1.62
# 13  1984  Eastern Mediterranean   Afghanistan          Other           0.00
# 18  1984                 Europe        Norway        Spirits           1.62
# 20  1986        South-East Asia       Myanmar           Wine           0.00

# %% [markdown]
# ### Write a Pandas program to filter those records which not appears in a given list from world alcohol consumption dataset.

# %%
df[~df["Beverage Types"].isin(['Wine', 'Spirit'])]
# Out:
#     Year WHO region                Country Beverage Types  Display Value
# 1   1986   Americas                Uruguay          Other           0.50
# 3   1986   Americas               Colombia           Beer           4.27
# 4   1987   Americas  Saint Kitts and Nevis           Beer           1.98
# 5   1987   Americas              Guatemala          Other           0.00
# 7   1985     Africa                 Angola        Spirits           0.39
# ..   ...        ...                    ...            ...            ...
# 91  1989     Europe               Bulgaria           Beer           4.43
# 92  1986     Africa                Eritrea        Spirits           0.00
# 93  1987     Africa             Madagascar          Other            NaN
# 94  1985     Europe                Ukraine        Spirits           3.06
# 95  1984     Africa                  Niger          Other           0.00
#
# [73 rows x 5 columns]

# %% [markdown]
# ### Write a Pandas program to filter all records where the average consumption of beverages per person from .5 to 2.50 in world alcohol consumption dataset

# %%
df[(df['Display Value']>0.5) & ((df['Display Value']<2.5))]
# Out:
#     Year             WHO region  \
# 2   1985                 Africa
# 4   1987               Americas
# 8   1986               Americas
# 11  1989               Americas
# 17  1989                 Africa
# 18  1984                 Europe
# 19  1984                 Africa
# 26  1985                 Europe
# 27  1984  Eastern Mediterranean
# 32  1989                 Africa
# 34  1986                 Europe
# 35  1985               Americas
# 40  1987                 Europe
# 46  1987               Americas
# 48  1987               Americas
# 49  1986                 Europe
# 54  1984               Americas
# 64  1989               Americas
# 70  1986                 Africa
# 71  1985                 Africa
# 74  1986               Americas
# 79  1989                 Europe
# 80  1985                 Africa
# 82  1987                 Europe
# 86  1986               Americas
# 89  1986  Eastern Mediterranean
#
#                                               Country Beverage Types  \
# 2                                        Cte d'Ivoire           Wine
# 4                               Saint Kitts and Nevis           Beer
# 8                                 Antigua and Barbuda        Spirits
# 11                                          Guatemala           Beer
# 17                                         Seychelles           Beer
# 18                                             Norway        Spirits
# 19                                              Kenya           Beer
# 26  United Kingdom of Great Britain and Northern I...           Wine
# 27                                            Bahrain           Beer
# 32                                          Mauritius           Beer
# 34                                 Russian Federation           Wine
# 35                              Saint Kitts and Nevis        Spirits
# 40                                            Austria        Spirits
# 46                                Trinidad and Tobago        Spirits
# 48                                          Nicaragua           Beer
# 49                                              Malta           Wine
# 54                                        El Salvador        Spirits
# 64                   Bolivia (Plurinational State of)           Beer
# 70                                         Madagascar        Spirits
# 71                                               Mali          Other
# 74                   Bolivia (Plurinational State of)        Spirits
# 79                                            Finland          Other
# 80                                             Malawi          Other
# 82                                            Ireland        Spirits
# 86                                            Bahamas           Wine
# 89                                            Lebanon           Wine
#
#     Display Value
# 2            1.62
# 4            1.98
# 8            1.55
# 11           0.62
# 17           2.23
# 18           1.62
# 19           1.08
# 26           1.36
# 27           2.22
# 32           1.60
# 34           0.80
# 35           2.24
# 40           1.90
# 46           2.26
# 48           0.70
# 49           1.49
# 54           1.81
# 64           1.26
# 70           1.02
# 71           0.57
# 74           2.06
# 79           2.09
# 80           0.84
# 82           2.25
# 86           1.83
# 89           0.70

# %% [markdown]
# ### Write a Pandas program to find number of consumption of wine per person greater than 2 in world alcohol consumption dataset.

# %%
df[(df['Display Value']>2) & (df['Beverage Types'] == 'Wine')]
# Out:
#     Year WHO region      Country Beverage Types  Display Value
# 57  1989     Europe      Croatia           Wine           5.10
# 81  1985     Europe  Netherlands           Wine           2.54
# 96  1985     Europe   Luxembourg           Wine           7.38

# %% [markdown]
# ### Write a Pandas program to filter rows based on row numbers ended with 0, like 0, 10, 20, 30 from world alcohol consumption dataset.

# %%
df.filter(regex='0$',axis=0)
# Out:
#     Year             WHO region                     Country Beverage Types  \
# 0   1986        Western Pacific                    Viet Nam           Wine
# 10  1987                 Africa                    Botswana           Wine
# 20  1986        South-East Asia                     Myanmar           Wine
# 30  1986                 Africa                Sierra Leone          Other
# 40  1987                 Europe                     Austria        Spirits
# 50  1985                 Europe                 Switzerland          Other
# 60  1987  Eastern Mediterranean  Iran (Islamic Republic of)          Other
# 70  1986                 Africa                  Madagascar        Spirits
# 80  1985                 Africa                      Malawi          Other
# 90  1989                 Africa                      Malawi           Wine
#
#     Display Value
# 0            0.00
# 10           0.20
# 20           0.00
# 30           4.48
# 40           1.90
# 50           0.30
# 60           0.00
# 70           1.02
# 80           0.84
# 90           0.01

# %% [markdown]
# ### Write a Pandas program to select consecutive columns and also select rows with Index label 0 to 9 with some columns from world alcohol consumption dataset.

# %%
df.loc[0:9,'Country':'Display Value']

# %% [markdown]
# ### Write a Pandas program to filter all records starting from the 2nd row, access every 5th row from world alcohol consumption dataset.

# %%
df.loc[2::5]
# Out:
#     Year             WHO region                           Country  \
# 2   1985                 Africa                      Cte d'Ivoire
# 7   1985                 Africa                            Angola
# 12  1985        Western Pacific  Lao People's Democratic Republic
# 17  1989                 Africa                        Seychelles
# 22  1984                 Europe                           Romania
# 27  1984  Eastern Mediterranean                           Bahrain
# 32  1989                 Africa                         Mauritius
# 37  1986                 Europe                            Sweden
# 42  1984                 Europe                           Ukraine
# 47  1986               Americas                            Mexico
# 52  1986  Eastern Mediterranean                      Saudi Arabia
# 57  1989                 Europe                           Croatia
# 62  1987               Americas                          Suriname
# 67  1989                 Africa                           Namibia
# 72  1987                 Africa                        Mauritania
# 77  1985                 Africa                          Cameroon
# 82  1987                 Europe                           Ireland
# 87  1989  Eastern Mediterranean                              Iraq
# 92  1986                 Africa                           Eritrea
# 97  1984        South-East Asia                         Indonesia
#
#    Beverage Types  Display Value
# 2            Wine           1.62
# 7         Spirits           0.39
# 12           Beer           0.00
# 17           Beer           2.23
# 22        Spirits           2.67
# 27           Beer           2.22
# 32           Beer           1.60
# 37           Beer           3.04
# 42        Spirits           3.06
# 47          Other           0.04
# 52           Wine           0.00
# 57           Wine           5.10
# 62          Other           0.00
# 67           Beer           0.00
# 72          Other           0.00
# 77        Spirits           0.01
# 82        Spirits           2.25
# 87           Wine           0.01
# 92        Spirits           0.00
# 97           Wine           0.00

# %% [markdown]
# ### Write a Pandas program to split the following dataframe into groups based on school code. Also check the type of GroupBy object.

# %%
student_data = pd.DataFrame({
    'school_code': ['s001','s002','s003','s001','s002','s004'],
    'class': ['V', 'V', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco','Gino Mcneill','Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'date_Of_Birth ': ['15/05/2002','17/05/2002','16/02/1999','25/09/1998','11/05/2002','15/09/1997'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4']},
    index=['S1', 'S2', 'S3', 'S4', 'S5', 'S6'])
student_data.head(10)
# Out:
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S2        s002     V    Gino Mcneill     17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes     16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
# S5        s002     V    Gino Mcneill     11/05/2002   14     151      31
# S6        s004    VI    David Parkes     15/09/1997   12     159      32
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4

# %%
student_by_code=student_data.groupby('school_code')
student_by_code.head()
# Out:
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S2        s002     V    Gino Mcneill     17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes     16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
# S5        s002     V    Gino Mcneill     11/05/2002   14     151      31
# S6        s004    VI    David Parkes     15/09/1997   12     159      32
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4

# %%
type(student_by_code)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# ### Write a Pandas program to split the following given dataframe into groups based on school code and class.

# %%
student_data.groupby(by=['school_code', 'class']).head()
# Out:
#    school_code class            name date_Of_Birth   age  height  weight  \
# S1        s001     V  Alberto Franco     15/05/2002   12     173      35
# S2        s002     V    Gino Mcneill     17/05/2002   12     192      32
# S3        s003    VI     Ryan Parkes     16/02/1999   13     186      33
# S4        s001    VI    Eesha Hinton     25/09/1998   13     167      30
# S5        s002     V    Gino Mcneill     11/05/2002   14     151      31
# S6        s004    VI    David Parkes     15/09/1997   12     159      32
#
#     address
# S1  street1
# S2  street2
# S3  street3
# S4  street1
# S5  street2
# S6  street4

# %% [markdown]
# ### Create a dataframe of ten rows, four columns with random values. Convert some values to nan values. Write a Pandas program which will highlight the nan values.

# %%
data=pd.DataFrame(np.random.randint(0,200, size=(10,4)))
data
# Out:
#      0    1    2    3
# 0  185   33  169  178
# 1   99  130  133   91
# 2   97  191  141  144
# 3   10  120   34   56
# 4  178   94   94  176
# 5  114  102  190   83
# 6   11   26  139  190
# 7   52    5   57  174
# 8  161   49  131  151
# 9    4   57  119   63

# %%
data.loc[1,3]=np.NaN
data.loc[3,3]=np.NaN
data.loc[7,3]=np.NaN
data.loc[2,2]=np.NaN

data
# Out:
#      0    1      2      3
# 0  185   33  169.0  178.0
# 1   99  130  133.0    NaN
# 2   97  191    NaN  144.0
# 3   10  120   34.0    NaN
# 4  178   94   94.0  176.0
# 5  114  102  190.0   83.0
# 6   11   26  139.0  190.0
# 7   52    5   57.0    NaN
# 8  161   49  131.0  151.0
# 9    4   57  119.0   63.0

# %%
data.style.highlight_null('red')
# Out:
# <style type="text/css">
# #T_afaec_row1_col3, #T_afaec_row2_col2, #T_afaec_row3_col3, #T_afaec_row7_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_afaec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_afaec_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_afaec_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_afaec_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_afaec_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_afaec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_afaec_row0_col0" class="data row0 col0" >185</td>
#       <td id="T_afaec_row0_col1" class="data row0 col1" >33</td>
#       <td id="T_afaec_row0_col2" class="data row0 col2" >169.000000</td>
#       <td id="T_afaec_row0_col3" class="data row0 col3" >178.000000</td>
#     </tr>
#     <tr>
#       <th id="T_afaec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_afaec_row1_col0" class="data row1 col0" >99</td>
#       <td id="T_afaec_row1_col1" class="data row1 col1" >130</td>
#       <td id="T_afaec_row1_col2" class="data row1 col2" >133.000000</td>
#       <td id="T_afaec_row1_col3" class="data row1 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_afaec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_afaec_row2_col0" class="data row2 col0" >97</td>
#       <td id="T_afaec_row2_col1" class="data row2 col1" >191</td>
#       <td id="T_afaec_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_afaec_row2_col3" class="data row2 col3" >144.000000</td>
#     </tr>
#     <tr>
#       <th id="T_afaec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_afaec_row3_col0" class="data row3 col0" >10</td>
#       <td id="T_afaec_row3_col1" class="data row3 col1" >120</td>
#       <td id="T_afaec_row3_col2" class="data row3 col2" >34.000000</td>
#       <td id="T_afaec_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_afaec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_afaec_row4_col0" class="data row4 col0" >178</td>
#       <td id="T_afaec_row4_col1" class="data row4 col1" >94</td>
#       <td id="T_afaec_row4_col2" class="data row4 col2" >94.000000</td>
#       <td id="T_afaec_row4_col3" class="data row4 col3" >176.000000</td>
#     </tr>
#     <tr>
#       <th id="T_afaec_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_afaec_row5_col0" class="data row5 col0" >114</td>
#       <td id="T_afaec_row5_col1" class="data row5 col1" >102</td>
#       <td id="T_afaec_row5_col2" class="data row5 col2" >190.000000</td>
#       <td id="T_afaec_row5_col3" class="data row5 col3" >83.000000</td>
#     </tr>
#     <tr>
#       <th id="T_afaec_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_afaec_row6_col0" class="data row6 col0" >11</td>
#       <td id="T_afaec_row6_col1" class="data row6 col1" >26</td>
#       <td id="T_afaec_row6_col2" class="data row6 col2" >139.000000</td>
#       <td id="T_afaec_row6_col3" class="data row6 col3" >190.000000</td>
#     </tr>
#     <tr>
#       <th id="T_afaec_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_afaec_row7_col0" class="data row7 col0" >52</td>
#       <td id="T_afaec_row7_col1" class="data row7 col1" >5</td>
#       <td id="T_afaec_row7_col2" class="data row7 col2" >57.000000</td>
#       <td id="T_afaec_row7_col3" class="data row7 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_afaec_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_afaec_row8_col0" class="data row8 col0" >161</td>
#       <td id="T_afaec_row8_col1" class="data row8 col1" >49</td>
#       <td id="T_afaec_row8_col2" class="data row8 col2" >131.000000</td>
#       <td id="T_afaec_row8_col3" class="data row8 col3" >151.000000</td>
#     </tr>
#     <tr>
#       <th id="T_afaec_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_afaec_row9_col0" class="data row9 col0" >4</td>
#       <td id="T_afaec_row9_col1" class="data row9 col1" >57</td>
#       <td id="T_afaec_row9_col2" class="data row9 col2" >119.000000</td>
#       <td id="T_afaec_row9_col3" class="data row9 col3" >63.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Create a dataframe of ten rows, four columns with random values. Write a Pandas program to highlight dataframe’s specific columns with different colors.

# %%
def column_color(s):
    color = 'blue'
    return 'background-color: %s' % color

data.style.applymap(column_color, subset=pd.IndexSlice[:,3])
# Out:
# <style type="text/css">
# #T_358a1_row0_col3, #T_358a1_row1_col3, #T_358a1_row2_col3, #T_358a1_row3_col3, #T_358a1_row4_col3, #T_358a1_row5_col3, #T_358a1_row6_col3, #T_358a1_row7_col3, #T_358a1_row8_col3, #T_358a1_row9_col3 {
#   background-color: blue;
# }
# </style>
# <table id="T_358a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_358a1_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_358a1_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_358a1_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_358a1_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_358a1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_358a1_row0_col0" class="data row0 col0" >185</td>
#       <td id="T_358a1_row0_col1" class="data row0 col1" >33</td>
#       <td id="T_358a1_row0_col2" class="data row0 col2" >169.000000</td>
#       <td id="T_358a1_row0_col3" class="data row0 col3" >178.000000</td>
#     </tr>
#     <tr>
#       <th id="T_358a1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_358a1_row1_col0" class="data row1 col0" >99</td>
#       <td id="T_358a1_row1_col1" class="data row1 col1" >130</td>
#       <td id="T_358a1_row1_col2" class="data row1 col2" >133.000000</td>
#       <td id="T_358a1_row1_col3" class="data row1 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_358a1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_358a1_row2_col0" class="data row2 col0" >97</td>
#       <td id="T_358a1_row2_col1" class="data row2 col1" >191</td>
#       <td id="T_358a1_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_358a1_row2_col3" class="data row2 col3" >144.000000</td>
#     </tr>
#     <tr>
#       <th id="T_358a1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_358a1_row3_col0" class="data row3 col0" >10</td>
#       <td id="T_358a1_row3_col1" class="data row3 col1" >120</td>
#       <td id="T_358a1_row3_col2" class="data row3 col2" >34.000000</td>
#       <td id="T_358a1_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_358a1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_358a1_row4_col0" class="data row4 col0" >178</td>
#       <td id="T_358a1_row4_col1" class="data row4 col1" >94</td>
#       <td id="T_358a1_row4_col2" class="data row4 col2" >94.000000</td>
#       <td id="T_358a1_row4_col3" class="data row4 col3" >176.000000</td>
#     </tr>
#     <tr>
#       <th id="T_358a1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_358a1_row5_col0" class="data row5 col0" >114</td>
#       <td id="T_358a1_row5_col1" class="data row5 col1" >102</td>
#       <td id="T_358a1_row5_col2" class="data row5 col2" >190.000000</td>
#       <td id="T_358a1_row5_col3" class="data row5 col3" >83.000000</td>
#     </tr>
#     <tr>
#       <th id="T_358a1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_358a1_row6_col0" class="data row6 col0" >11</td>
#       <td id="T_358a1_row6_col1" class="data row6 col1" >26</td>
#       <td id="T_358a1_row6_col2" class="data row6 col2" >139.000000</td>
#       <td id="T_358a1_row6_col3" class="data row6 col3" >190.000000</td>
#     </tr>
#     <tr>
#       <th id="T_358a1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_358a1_row7_col0" class="data row7 col0" >52</td>
#       <td id="T_358a1_row7_col1" class="data row7 col1" >5</td>
#       <td id="T_358a1_row7_col2" class="data row7 col2" >57.000000</td>
#       <td id="T_358a1_row7_col3" class="data row7 col3" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_358a1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_358a1_row8_col0" class="data row8 col0" >161</td>
#       <td id="T_358a1_row8_col1" class="data row8 col1" >49</td>
#       <td id="T_358a1_row8_col2" class="data row8 col2" >131.000000</td>
#       <td id="T_358a1_row8_col3" class="data row8 col3" >151.000000</td>
#     </tr>
#     <tr>
#       <th id="T_358a1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_358a1_row9_col0" class="data row9 col0" >4</td>
#       <td id="T_358a1_row9_col1" class="data row9 col1" >57</td>
#       <td id="T_358a1_row9_col2" class="data row9 col2" >119.000000</td>
#       <td id="T_358a1_row9_col3" class="data row9 col3" >63.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Write a Pandas program to display the dataframe in Heatmap style

# %%
sns.heatmap(data, annot=True)
# Out:
# <Axes: >
